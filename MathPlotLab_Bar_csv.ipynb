# %% [markdown]
# <a href="https://colab.research.google.com/github/FazulNoor/IBMWatson/blob/main/MathPlotLab_Bar_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as py
import numpy as np
import pandas as pd
from collections import Counter

py.style.use('fivethirtyeight')

data = pd.read_csv('data.csv')
ids = data['Responder_id']
lang_responses = data['LanguagesWorkedWith']

language_counter = Counter()

x_indexes=np.arange(len(dev_x))

# %%
for response in lang_responses:
  language_counter.update(response.split(";"))
  
# print(language_counter)
languages = []
popularity = []

for item in language_counter.most_common(15):
  languages.append(item[0])
  popularity.append(item[1])

languages.reverse()
popularity.reverse()

# %%
py.barh(languages,popularity)
py.xlabel('Popularity')
py.title('Languages in popularity')
py.show()
